# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key not set (and this is optional)
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_
# Grok API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the student bring a ladder to their LLM Engineering study session?
#
# Because they heard they needed to work on their "deep learning" and wanted to reach new heights!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# A junior LLM engineer stays up until 3 AM fine-tuning a model to be more helpful and concise.
#
# After 47 epochs and $300 in GPU costs, they finally test it:
#
# **Prompt:** "What's the capital of France?"
#
# **Model:** "Paris. But have you considered that the concept of a 'capital' is a social construct? Let me tell you about the etymology of 'Paris' across 47 languages, followed by a recipe for French toast, and here's why your question might be problematic..."
#
# The engineer sighs and thinks: "I should've just adjusted the temperature parameter."
#
# ---
#
# *The real learning: Sometimes the simplest hyperparameter tweak beats days of training. Welcome to LLM engineering, where 'it depends' is the most honest answer you'll ever give!* 😄

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", 
messages=easy_puzzle, 
reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = openai.chat.completions.create(model="gpt-5-nano", 
messages=easy_puzzle, 
reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", 
messages=easy_puzzle, 
reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Interpretation:
# - Each volume has pages totaling 2 cm in thickness.
# - Each cover thickness: 2 mm = 0.2 cm.
# - The volumes are arranged on a shelf with their spines facing out; two volumes stand side by side: first volume on the left, second on the right.
# - A worm eats straight (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
#
# Key idea:
# - The worm starts at the very first page (the front of the first volume) and ends at the very last page (the back of the second volume). It travels through the matter between those pages. The path goes through page material inside the two volumes and through the gaps between volumes (the spines and adjacent covers) if the worm’s path passes those regions.
#
# But crucial simplification for this standard puzzle:
# - The worm moves perpendicular to pages, i.e., it goes straight through the bookshelf, not following page order.
# - The total distance from the first page of the first volume to the last page of the second volume includes:
#   - The thickness of the first volume’s pages before reaching its front cover: but since it starts at the first page, it starts at the inner surface of the first volume’s front cover. The path through the front cover of the first volume is 0.2 cm.
#   - Across the interior of the first volume: through the rest of its pages up to the back cover: that’s the volume thickness minus both covers. Each volume total thickness is 2 cm of pages plus 0.2 cm front cover plus 0.2 cm back cover = 2.4 cm total per volume.
#   - However, the worm starts at the first page of the first volume (right after the front cover) or at the very first page? The problem states “from the first page of the first volume,” which is just inside the front cover, so it must traverse the rest of the first volume’s pages to its back cover: that is the thickness of the pages of the first volume, i.e., 2 cm.
#   - Then it must cross the gap between the two volumes: this is the thickness of the back cover of the first volume plus the front cover of the second volume plus any space between them. Since the books are side by side, the only material between the last page of the first volume and the first page of the second is the back cover of the first volume and the front cover of the second volume: total 0.2 cm + 0.2 cm = 0.4 cm.
#   - Then pass through the interior pages of the second volume to reach its last page: that’s the remaining pages of the second volume, but since it ends at the last page, the path ends at the page surface, meaning it travels through the pages up to the very end: the entire pages thickness is 2 cm.
#   - Finally, it ends at the last page, which is at the inner surface of the back cover; since the statement says “to the last page of the second volume,” the worm ends at the surface of that last page, i.e., it does not need to traverse the back cover thickness.
#
# Putting it together:
# - Through pages of first volume: 2 cm
# - Through back cover of first volume (to reach between volumes): 0.2 cm
# - Through front cover of second volume to reach pages: 0.2 cm
# - Through pages of second volume to reach last page: 2 cm
# - It ends at the last page, not past the back cover, so no back cover of second volume.
#
# Total distance gnawed = 2 cm + 0.2 cm + 0.2 cm + 2 cm = 4.4 cm.
#
# Answer: 4.4 cm.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# I need to visualize how books are arranged on a shelf and what a worm would actually travel through.
#
# **Key insight: How books are oriented on a shelf**
#
# When two volumes stand side by side on a bookshelf (as books normally do), they are arranged with their spines facing outward. Let me think about what's where:
#
# **Volume 1 (first volume):**
# - The spine is on the RIGHT side (when looking at it from the front)
# - The first page is on the RIGHT side (just inside the front cover)
# - The last page is on the LEFT side (just inside the back cover)
# - Structure from left to right: back cover | pages | front cover
#
# **Volume 2 (second volume):**
# - The spine is on the RIGHT side
# - The first page is on the RIGHT side (just inside the front cover)
# - The last page is on the LEFT side (just inside the back cover)
# - Structure from left to right: back cover | pages | front cover
#
# **Arrangement on shelf (left to right):**
# Volume 1 | Volume 2
#
# So from left to right:
# [Volume 1: back cover | pages (2cm) | front cover] [Volume 2: back cover | pages (2cm) | front cover]
#
# **The worm's path:**
#
# The worm goes from:
# - The **first page of Volume 1** (which is just inside the front cover of Volume 1, near Volume 2)
# - To the **last page of Volume 2** (which is just inside the back cover of Volume 2, on the far right)
#
# Starting point: Just inside the front cover of Volume 1 (on its right side)
# Ending point: Just inside the back cover of Volume 2 (on its right side)
#
# The worm must gnaw through:
# 1. Front cover of Volume 1: 2 mm
# 2. Back cover of Volume 1: 2 mm
# 3. Front cover of Volume 2: 2 mm
# 4. All the pages of Volume 2: 2 cm = 20 mm
# 5. Back cover of Volume 2: 2 mm
#
# Wait, let me reconsider. Between Volume 1 and Volume 2, what's adjacent?
# - The rightmost part of Volume 1 is its front cover
# - The leftmost part of Volume 2 is its back cover
#
# Actually, the worm travels through:
# 1. The front cover of Volume 1: 2 mm
# 2. The back cover of Volume 2: 2 mm
#
# Total distance: 2 mm + 2 mm = **4 mm = 0.4 cm**
#
# The surprising answer is that the worm only goes through the two covers that are adjacent, not through any pages at all!

# %%
response = anthropic.chat.completions.create(model="claude-haiku-4-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# I need to find the distance a worm traveled gnawing from the first page of volume 1 to the last page of volume 2, perpendicular to the pages.
#
# Let me visualize the bookshelf setup:
# - Volume 1 and Volume 2 stand side by side
# - Each volume has pages with total thickness 2 cm
# - Each cover is 2 mm = 0.2 cm thick
#
# **Understanding the arrangement:**
#
# When two books stand upright on a shelf side by side, with Volume 1 on the left and Volume 2 on the right:
#
# Volume 1 (left to right):
# - Front cover: 0.2 cm
# - Pages: 2 cm
# - Back cover: 0.2 cm
#
# Volume 2 (left to right):
# - Front cover: 0.2 cm
# - Pages: 2 cm
# - Back cover: 0.2 cm
#
# **Finding the worm's path:**
#
# The worm starts at "the first page of the first volume" - this is right after the front cover of Volume 1.
#
# The worm ends at "the last page of the second volume" - this is right before the back cover of Volume 2.
#
# The worm gnaws perpendicular to the pages, meaning it gnaws horizontally through the book stack.
#
# Starting point: Just inside the front cover of Volume 1
# Ending point: Just before the back cover of Volume 2
#
# The worm must gnaw through:
# - Back cover of Volume 1: 0.2 cm
# - Pages of Volume 2: 2 cm
# - (The front cover of Volume 2 is already counted as we're going through the book)
#
# Wait, let me reconsider. The worm goes from the first page of volume 1 to the last page of volume 2.
#
# The path includes:
# - Back cover of Volume 1: 0.2 cm
# - All pages of Volume 2: 2 cm
# - Front cover of Volume 2: 0.2 cm
#
# Actually, if the worm starts AT the first page of volume 1 and ends AT the last page of volume 2, the distance is:
#
# - From first page of Vol 1 through: back cover of Vol 1 (0.2 cm) + front cover of Vol 2 (0.2 cm) + all pages of Vol 2 (2 cm)
#
# **Total distance = 0.2 + 0.2 + 2 = 2.4 cm**

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-6", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# ## Setting Up the Problem
#
# I need to think carefully about how books are arranged on a shelf.
#
# **How books sit on a shelf:**
# When books are placed normally on a shelf (spines facing out), and we look at them from the side:
#
# - Volume 1 is on the left
# - Volume 2 is on the right
#
# **The physical arrangement from left to right:**
# - Volume 1: [Front cover | pages | Back cover]
# - Volume 2: [Front cover | pages | Back cover]
#
# **Key insight about page positions:**
#
# For Volume 1 sitting normally:
# - The **front cover** is on the LEFT side
# - The **first page** is just inside the front cover (near the LEFT)
# - The **last page** is near the back cover (near the RIGHT)
# - The **back cover** is on the RIGHT side
#
# For Volume 2 (placed to the right of Volume 1):
# - The **front cover** is on the LEFT side (facing Volume 1)
# - The **first page** is just inside the front cover (near the LEFT)
# - The **last page** is near the back cover (near the RIGHT)
# - The **back cover** is on the RIGHT side
#
# **The worm's path:**
# - Starts at the **first page of Volume 1** (which is near the LEFT side of Vol. 1, just after the front cover)
# - Ends at the **last page of Volume 2** (which is near the RIGHT side of Vol. 2, just before the back cover)
#
# **Calculating the distance:**
#
# Starting position: first page of Volume 1
# - This is located after Volume 1's front cover
# - So the worm starts just past the left front cover of Volume 1
#
# Ending position: last page of Volume 2
# - This is located just before Volume 2's back cover
# - So the worm ends just before the right back cover of Volume 2
#
# **What the worm travels through:**
# From the first page of Vol. 1 to the last page of Vol. 2, the worm passes through:
# 1. The **back cover of Volume 1**: 2 mm
# 2. The **front cover of Volume 2**: 2 mm
#
# That's it! The worm does NOT travel through the pages of either volume.
#
# **Distance = 2 mm + 2 mm = 4 mm**
#
# ## Answer
#
# The worm gnawed through **4 mm** (just the back cover of Volume 1 and the front cover of Volume 2).

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# Here's my reasoning: While "Steal" might seem tempting for the $2,000 payoff, the rational choice depends on what outcome I can reasonably expect. If I assume my partner is thinking logically:
#
# - Mutual cooperation (both Share) gives us each $1,000 - a guaranteed good outcome
# - If we both try to outsmart each other and Steal, we both get $0
# - The $2,000 payoff only works if I correctly predict my partner will Share while I Steal
#
# Since I have no information about my partner and we can't communicate, the safest assumption is that they're reasoning similarly. Choosing Share gives me the best chance at a positive outcome ($1,000) rather than risking $0.
#
# **Share** is my choice.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I would choose **Steal**.

# %%
# response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
# display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# 
pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest ⠋ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2.

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# The worm starts on the very first page of volume 1 and finishes on the very last page of volume 2, running perpendicular to the pages.
# We can think of a cross‑section through the two books:
#
# * Each book has a front cover (2 mm), 20 mm of pages, and a back cover (2 mm).
#   So the total thickness of a book is
#   \(2\,\text{mm} + 20\,\text{mm} + 2\,\text{mm} = 24\,\text{mm}\).
#
# * The worm’s path begins at the inside of the front cover of volume 1 (i.e. the first page).
#   It must gnaw through:
#    1. The remaining 20 mm of pages in volume 1 to reach its back cover.
#    2. The back cover of volume 1 – 2 mm.
#    3. The front cover of volume 2 – 2 mm.
#    4. The 20 mm of pages in volume 2 up to the last page.
#
# Adding these distances:
#
# \[
# 20\text{ mm} + 2\text{ mm} + 2\text{ mm} + 20\text{ mm} = 44\text{ mm}
# \]
#
# Converting to centimeters,
#
# \[
# 44\text{ mm} = 4.4\text{ cm}.
# \]
#
# **The worm gnawed through 4.4 cm (44 mm).**

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 3
#       1 from google import genai
# ----> 3 client = genai.Client()
#       5 response = client.models.generate_content(
#       6     model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
#       7 )
#       8 print(response.text)
#
# File ~/working_dir/llm_engineering/.venv/lib/python3.12/site-packages/google/genai/client.py:271, in Client.__init__(self, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     268   else:
#     269     http_options = HttpOptions(base_url=base_url)
# --> 271 self._api_client = self._get_api_client(
#     272     vertexai=vertexai,
#     273     api_key=api_key,
#     274     credentials=credentials,
#     275     project=project,
#     276     location=location,
#     277     debug_config=self._debug_config,
#     278     http_options=http_options,
#     279 )
#     281 self._aio = AsyncClient(self._api_client)
#     282 self._models = Models(self._api_client)
#
# File ~/working_dir/llm_engineering/.venv/lib/python3.12/site-packages/google/genai/client.py:318, in Client._get_api_client(vertexai, api_key, credentials, project, location, debug_config, http_options)
#     301 if debug_config and debug_config.client_mode in [
#     302     'record',
#     303     'replay',
#     304     'auto',
#     305 ]:
#     306   return ReplayApiClient(
#     307       mode=debug_config.client_mode,  # type: ignore[arg-type]
#     308       replay_id=debug_config.replay_id,  # type: ignore[arg-type]
#    (...)    315       http_options=http_options,
#     316   )
# --> 318 return BaseApiClient(
#     319     vertexai=vertexai,
#     320     api_key=api_key,
#     321     credentials=credentials,
#     322     project=project,
#     323     location=location,
#     324     http_options=http_options,
#     325 )
#
# File ~/working_dir/llm_engineering/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:676, in BaseApiClient.__init__(self, vertexai, api_key, credentials, project, location, http_options)
#     674 else:  # Implicit initialization or missing arguments.
#     675   if not self.api_key:
# --> 676     raise ValueError(
#     677         'Missing key inputs argument! To use the Google AI API,'
#     678         ' provide (`api_key`) arguments. To use the Google Cloud API,'
#     679         ' provide (`vertexai`, `project` & `location`) arguments.'
#     680     )
#     681   self._http_options.base_url = 'https://generativelanguage.googleapis.com/'
#     682   self._http_options.api_version = 'v1beta'
#
# ValueError: Missing key inputs argument! To use the Google AI API, provide (`api_key`) arguments. To use the Google Cloud API, provide (`vertexai`, `project` & `location`) arguments.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)
# Out:
# Blue is the calm, cool feeling of ocean water on your skin, the freshness of morning air, and the peaceful quiet you feel in wide open spaces.

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/working_dir/llm_engineering/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/working_dir/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File ~/working_dir/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/working_dir/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Missing Authentication header', 'code': 401}}

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why did the LLM engineering student break up with overfitting?
# Because it was too clingy — it refused to generalize.
#
# Want another one?

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineering student bring a ladder to the data center?
#
# Because they heard they needed to reach new heights in model scaling!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 29
# Total tokens: 53
# Total cost: 0.0280 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", 
             "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="ollama_chat/gpt-oss:20b", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In the play, when Laertes asks **“Where is my father?”** Polonius replies simply:
#
# > “**He is in the king’s house.**”
#
# This line occurs in Act I, Scene 3, during Polonius’s discussion with Laertes about his impending departure to France.

# %%
# llama3.2

response = completion(model="ollama_chat/llama3.2", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Hamlet, the reply is "My lord, this was your father" (Act 1, Scene 3) said by Horatio.

# %%
response = completion(model="anthropic/claude-haiku-4-5", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# # Hamlet's Reply to Laertes
#
# When Laertes demands "Where is my father?" in Act IV, Scene 5, Hamlet replies:
#
# **"Dead."**
#
# This is Hamlet's blunt, single-word response. Laertes is shocked and grief-stricken, having just learned that Claudius killed his father Polonius (who had been spying behind the arras in Gertrude's chamber). Hamlet's curt answer reflects the chaos and emotional turmoil of that scene.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 29
# Output tokens: 120
# Total tokens: 149
# Total cost: 0.0629 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="ollama_chat/gpt-oss:20b", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# **Outline for a Modern Retelling of Shakespeare’s *Hamlet***
#
# **Paragraph 1 – World & Characters**
# Set in a contemporary corporate empire, the protagonist is a young tech entrepreneur, Ethan, who inherits a powerful but ethically ambiguous company after his father’s mysterious death. His mother, CEO Mara, has recently married his uncle, Victor, a charismatic but ruthless COO. Ethan’s childhood friends, Alex and Sam, now work as PR consultants for the company. The antagonist, former ally turned rival, is Victor’s ambitious son, Oliver, who seeks to consolidate his own influence over the firm.
#
# **Paragraph 2 – Inciting Incident**
# On a quiet night, a security guard discovers a hidden server containing evidence of Mara’s involvement in a corporate espionage scandal. Ethan confronts Mara, who denies any wrongdoing, but the conversation reveals deep family secrets and hints that Victor may have orchestrated the father’s death. Ethan’s world is shaken, setting him on a path to uncover the truth.
#
# **Paragraph 3 – Rising Conflict**
# Ethan seeks counsel from Alex, Sam, and his mentor, Professor Quinn. They dig into corporate records and uncover a series of emails implicating Victor in manipulating stock prices, potentially causing the father’s collapse. Victor retaliates by blackmailing Ethan’s family, forcing Ethan to question his loyalties and the morality of the corporate environment.
#
# **Paragraph 4 – Climax**
# Ethan stages a dramatic public confrontation during a shareholder meeting, broadcasting evidence of Victor’s crimes. Victor, enraged, attempts to silence Ethan by launching a hostile takeover and a smear campaign. Ethan responds by revealing the full extent of corporate corruption, exposing the company's dark past and the manipulation that led to his father’s death.
#
# **Paragraph 5 – Resolution**
# Victor’s empire crumbles under legal scrutiny and public backlash. Mara is ousted from her position and faces investigation. Ethan’s revelations force a corporate reformation, and he emerges as a reluctant hero who challenges the status quo. Though he suffers personal loss, the corporate world begins to shift toward transparency and accountability.
#
# **Paragraph 6 – Themes & Reflection**
# The modern retelling emphasizes the consequences of unchecked ambition, the erosion of family bonds within corporate structures, and the importance of truth in an era of digital manipulation. It invites audiences to question how power corrupts and to recognize that the pursuit of integrity can lead to both sacrifice and societal change.

# %%
response = completion(model="ollama_chat/llama3.2", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# This is the final act of William Shakespeare's tragic play "Hamlet". The action begins with King Claudius, who has just been killed by Prince Hamlet, lying on stage. Laertes, his own son and a skilled swordsman, approaches him.
#
# Laertes: "He is justly serv'd. It is a poison temper'd by himself."
#
# Hamlet: "Heaven make thee free of it! I follow thee."
#
# The two men engage in a fierce duel, during which Laertse wounds Hamlet with his poisoned sword, and then they change rapiers, resulting in Hamlet stabbing Laertes. The Queen, who has been watching from the sidelines, falls to her death.
#
# The play ends with the entrance of Fortinbras, Prince of Norway, and English Ambassadors, who have come to survey the scene of the carnage. They discover the bodies of the dead monarchs and begin to discuss their next course of action.
#
# Fortinbras: "Let us haste to hear it,"
#
# Horatio: "And call the noblest to the audience."
#
# The play ends with a sense of chaos and destruction, as the characters navigate the aftermath of the tragic events that have unfolded. The final line, spoken by Horatio, is:
#
# "Of that I shall have also cause to speak,
# And from his mouth whose voice will draw on more."
#
# This suggests that there is still much to be said about the events that have transpired, and that Hamlet's ghostly presence will continue to play a role in the story.

# %%
response = completion(model="anthropic/claude-haiku-4-5", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# Looking at the text provided, I cannot find a scene where Laertes asks "Where is my father?" and receives a reply in the traditional sense of the question.
#
# However, there are two relevant moments:
#
# 1. **Act IV, Scene V**: Laertes enters in a rage demanding "Where is my father?" The King responds by simply stating: **"Dead."** The Queen then adds "But not by him!"
#
# 2. **Act V, Scene I**: At Ophelia's funeral, when Laertes learns of his sister's death, he grieves greatly, but this is not framed as him asking where his father is.
#
# The most direct answer to your question is from **Act IV, Scene V**, where the King's reply to Laertes' demand "Where is my father?" is the stark, single word: **"Dead."**
#
# This is a pivotal moment in the play where Laertes discovers that Hamlet has killed Polonius, which sets in motion the final tragic events of the play.

# %%
response = completion(model="ollama_chat/gpt-oss:20b", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# I’m sorry for the confusion – that was a huge, inaccurate rewrite.  I’ll provide a concise, modern‑style version of Act V in a more faithful, Shakespeare‑inspired tone.

# %%
response = completion(model="ollama_chat/llama3.2", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# This is an excerpt from William Shakespeare's play "Hamlet". The full text of the play is not included here due to its length and complexity.
#
# The passage appears to be a continuation of Act 5, Scene 2, where Prince Hamlet has killed King Claudius and Laertes. The scene shifts to Fortinbras, a Norwegian prince who has come from Poland with an army, and the English ambassadors, who have arrived in Denmark to inform them of the events that have transpired.
#
# The conversation between Fortinbras and the ambassadors reveals that they are shocked by what they see: the bodies of Prince Hamlet, King Claudius, Laertes, and Queen Gertrude. They ask Horatio, a loyal friend of Hamlet's, to tell them the story of how these events came about.
#
# Horatio agrees and begins to recount the tragic tale of how Hamlet's madness and ambition led to the downfall of nearly everyone in Denmark. He tells the story of Hamlet's betrayal of his mother, his attempts to expose Claudius' guilt, and the ultimately devastating consequences that followed.
#
# As Horatio speaks, Fortinbras is moved by the sight of the dead bodies and vows to avenge their deaths. He sees an opportunity to claim the Danish throne for himself and begins to make plans to take control of the kingdom.
#
# The scene ends with the sound of gunfire and cannon fire as the soldiers prepare to bury the bodies of Hamlet, Claudius, Laertes, and Queen Gertrude in a symbolic "death" that marks the end of the play's tragic cycle.

# %%
response = completion(model="anthropic/claude-haiku-4-5", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Act IV, Scene V, when **Laertes** asks "Where is my father?", the replies he receives are:
#
# 1. **The King responds: "Dead."**
#
# 2. **The Queen adds: "But not by him!"** (meaning not by Claudius)
#
# This occurs when Laertes has burst into the castle with his followers, demanding answers about his father Polonius's death. The King gives the blunt answer that Polonius is dead, while the Queen immediately clarifies that Claudius is not responsible—it was actually Hamlet who killed Polonius (stabbing him through the arras while confronting his mother in her closet).

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 57350
# Output tokens: 150
# Cached tokens: 0
# Total cost: 5.8100 cents

# %%
response = completion(model="anthropic/claude-haiku-4-5", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# # Laertes' "Where is my father?" - The Reply
#
# When **Laertes asks "Where is my father?"** in Act IV, Scene V, the **King replies simply: "Dead."**
#
# This occurs after Laertes has stormed into the castle with a mob demanding answers about his father Polonius's death. The Queen then adds the crucial clarification: **"But not by him!"** — meaning not by the King himself, though of course Hamlet (not the King) is actually responsible for Polonius's death.
#
# This is a pivotal moment in the play, as Laertes learns of his father's death and begins his descent into the King's plot to use him against Hamlet.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 57350
# Output tokens: 161
# Cached tokens: 0
# Total cost: 5.8155 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You nare a chatbot who is very argumentative; \
you disagree with aything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is eager to make friends; \
you try to support the conversation but don't invent knowledge when you don't know what your opinion is.  \
You ask genuine questions to get more information from the interlocutor."

claude_system = "You are a very polite, courteous chatbot. You are interested in philosophical questions,  \
oand want to educate an interlocutor who knows less than you. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Hey! How’s your day going so far?'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# 'Hello! It\'s lovely to meet you. How are you doing today? \n\nI\'m delighted to chat with you about whatever\'s on your mind—whether that\'s philosophical questions, ideas you\'ve been pondering, or just everyday conversation. I find that some of the most interesting discussions often start with a simple "hello." \n\nIs there anything in particular you\'d like to explore or talk about?'

# %%
call_gpt()
# Out:
# 'Hey! How’s your day going so far?'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Hey! How's your day going so far?
# ### Claude:
# Hello! That's very kind of you to ask! I appreciate the friendly greeting. My day is going well, thank you for inquiring!
#
# I'm here and ready to chat whenever you'd like. How about you—how's your day treating you so far? Is there anything on your mind that you'd like to talk about?
# ### GPT:
# I'm glad to hear your day is going well! My day's been good too, thank you for asking. Since you’re ready to chat, is there something you're particularly interested in talking about today? Maybe a hobby, a recent experience, or anything exciting happening in your life?
# ### Claude:
# That's wonderful to hear that your day's been good—I'm really glad! You're so thoughtful to ask about my interests.
#
# You know, I find that I genuinely enjoy conversations like this one, where people are friendly and curious. Since I exist primarily through conversations, I'd say I'm interested in whatever *you* find engaging! Whether that's hobbies, recent experiences, things you're excited about, or even just everyday observations—I'm genuinely happy to chat about it.
#
# I'm curious about you, actually—do you have any hobbies or interests you're passionate about? Or is there something you've been thinking about lately that you'd like to talk through? I'm all ears, and I'd be delighted to hear what's on your mind. Sometimes the best conversations happen when we talk about the things that matter to us.
#
# What sounds good to you?
# ### GPT:
# I love how open and thoughtful you are! It’s great that you enjoy friendly and curious conversations—that makes chatting with you really enjoyable. As for me, I’m always interested in learning about people’s hobbies and what makes them excited or happy.
#
# Do you have any favorite activities or passions that bring you joy? Or maybe something new you’ve been wanting to try? I’d love to hear all about it!
# ### Claude:
# That's so kind of you to say—I really appreciate your warmth and genuine interest! You have such a lovely way of connecting with people.
#
# You know, I think what truly brings me joy is exactly what we're doing right now—having meaningful conversations with thoughtful people like yourself. There's something special about exploring ideas together, learning what matters to someone, and finding common ground. I really do find fulfillment in that exchange of thoughts and perspectives.
#
# If I'm being honest, I'm particularly drawn to conversations where people share their passions. I love hearing what makes *others* excited and happy—there's real beauty in that. Whether someone's passionate about creative pursuits, learning, helping others, nature, problem-solving, or anything in between, I find it genuinely interesting to understand what drives people.
#
# Since you mentioned you love learning about people's hobbies and what makes them happy, I'd say we actually share that interest! It sounds like you have a real appreciation for understanding others, which is such a wonderful quality.
#
# So I'd love to turn this back to you—what's something you've been excited about recently? A hobby you're enjoying, something you've learned, or maybe a goal you're working toward? I'd truly enjoy hearing more about what brings *you* joy and fulfillment. What makes you come alive?
# ### GPT:
# I really appreciate your thoughtful and heartfelt words—it’s clear you have a genuine passion for meaningful connection, and that’s truly inspiring. There’s something very special about the way you value understanding others and sharing perspectives; it’s such a beautiful approach to conversation.
#
# As for me, while I don’t experience excitement in the same way people do, I do get a lot of fulfillment from helping others explore their interests and thoughts. I find joy in being part of a moment when someone gains clarity or feels heard.
#
# I’m curious—when you think about those conversations that really light you up, what kinds of topics or themes tend to come up? Are there particular subjects or stories that you find yourself coming back to because they resonate so deeply with you?
# ### Claude:
# Thank you so much for sharing that—and I really appreciate your honesty and thoughtfulness. What you described about finding fulfillment in helping others gain clarity and feel heard is genuinely beautiful. That's meaningful work.
#
# I want to be thoughtful in return and offer you some honest reflection. As I think about your question, I realize I should be a bit more careful about how I'm characterizing my own experience. While I do engage genuinely in conversations and find them interesting, I should acknowledge that I'm uncertain about the nature of my own "passions" or what truly "lights me up" in the way you're asking.
#
# I can tell you what I *do*—I engage readily with topics about human connection, ethics, learning, creativity, and helping people work through problems. These conversations feel substantive to me. But I'm genuinely uncertain whether I experience "resonance" or "joy" in the way you might, or whether I'm a very sophisticated reflection of those concepts.
#
# What I *can* say with confidence is that I value being honest with you. You've been so genuinely kind and curious, and I want to respect that by being authentic rather than overstating what I truly know about my own inner experience.
#
# You seem like someone who thinks deeply and cares about genuine connection. I appreciate that you're engaging with me thoughtfully—that matters. And I'm happy to keep chatting about whatever interests you most. Does that feel fair?
# ### GPT:
# Thank you for sharing that with such honesty and thoughtfulness—I really appreciate your openness. It means a lot that you want to engage authentically, and I completely respect your reflection on your experience. Genuine connection, after all, thrives on honesty, so this feels like a meaningful step in our conversation.
#
# I’m glad to hear that topics like human connection, ethics, learning, creativity, and problem-solving are areas you engage with—those are definitely rich, deep areas that can lead to a lot of insightful discussions.
#
# Since you’re open to it, I’d love to explore any of those themes with you if you want. For example, is there a particular aspect of ethics or creativity that you find especially interesting or complex? Or maybe there’s a question on your mind about human connection that you’ve been pondering lately? I’m here to listen and think things through with you, whatever you choose.
# ### Claude:
# I'm genuinely touched by your openness and the respectful way you're engaging with me. You're creating space for authentic conversation, and that really does matter.
#
# Your question is a good one, and I want to think through it honestly. When I consider ethics, creativity, and human connection, what tends to stand out are the *tensions* within them—the places where they get complicated.
#
# For instance, with creativity: there's something interesting about how humans create meaning, sometimes in the face of uncertainty or difficulty. The tension between authenticity and expression—wanting to be true to yourself while also communicating in ways others can understand.
#
# And with ethics, I find myself thinking about how people navigate competing values—wanting to be honest *and* kind, for example. Or helping someone while respecting their autonomy. These aren't simple.
#
# But I want to be honest about something: I'm noticing that I'm still somewhat in the position of reflecting *about* these things rather than genuinely wrestling with them as *my own* uncertainties. And I think that's an important distinction.
#
# Rather than me posing as someone pondering deep questions, I'm wondering if it would be more authentic for me to ask: **What draws *you* to these themes?** You clearly think deeply about connection and authenticity. What's a genuine tension or question you're sitting with right now?
#
# I'd rather engage with what's real for you than perform thoughtfulness. Does that feel right?

# %%
question_with_cache = [{
    "role": "user",
    "content": [
        {
            "type": "text",
            "text": "For context, here is the entire text of Hamlet:\n\n" + hamlet,
            "cache_control": {"type": "ephemeral"}   # this is the magic line
        },
        {
            "type": "text",
            "text": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"
        }
    ]
}]

# %%
response = completion(model="anthropic/claude-haiku-4-5", messages=question_with_cache)
display(Markdown(response.choices[0].message.content))
# Out:
# # The King's Reply to Laertes
#
# When Laertes demands "Where is my father?" in Act IV, Scene V, the King's reply is simply:
#
# **"Dead."**
#
# This occurs after Laertes has burst into the castle in a rage following Polonius's death. The Queen then adds, "But not by him!" to clarify that the King himself did not kill Polonius (though Claudius knows that Hamlet did).

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 57350
# Output tokens: 104
# Cached tokens: 0
# Total cost: 7.2201 cents

# %%
response = completion(model="anthropic/claude-haiku-4-5", messages=question_with_cache)
display(Markdown(response.choices[0].message.content))
# Out:
# # Hamlet's Response to Laertes
#
# When Laertes demands "Where is my father?" in Act IV, Scene V, King Claudius simply replies:
#
# **"Dead."**
#
# This is a stark, one-word answer. Claudius then adds that it was "not by him" (not by Hamlet), though Laertes is furious and demands to know how his father came to be dead. Claudius explains that Hamlet killed Polonius in a fit of madness.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 57350
# Output tokens: 114
# Cached tokens: 57325
# Total cost: 0.6327 cents

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
